# %% [markdown]
# <a href="https://colab.research.google.com/github/ronakbihani123/RNN/blob/main/rnn_%2C_LSTM%2CGRU_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# what is LSTM and how it mitigate the problem of simplel RNN

# %%
# architecture of LSTM

# %%
# why cant a feed forward network handle sequence data effectively

# %%
# what wiull happen if forget gate output 1

# %%
# why is siggmoid and tanh used in /lstm gate

# %%
# what is bidirection LSTM

# %%
# what is GRU write the achitecture of GRU

# %%
# why gru preferred over lstm

# %%
# what happen if the update gate value become 1 and if it become 0

# %%
# why sigmoid and tanh used in GRU
